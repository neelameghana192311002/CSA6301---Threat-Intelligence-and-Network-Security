# %% [markdown]
# <a href="https://colab.research.google.com/github/neelameghana192311002/CSA6301---Threat-Intelligence-and-Network-Security/blob/main/ClassActivity/Ex2_Phishing_URL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

url = input("Enter URL: ")

# Simple phishing patterns
pattern = r"(login|verify|secure|update|bank).*\d"

if re.search(pattern, url):
    print("Possible Phishing URL")
else:
    print("Safe URL")
# Out:
# Enter URL: http://securebank123.com
# Possible Phishing URL

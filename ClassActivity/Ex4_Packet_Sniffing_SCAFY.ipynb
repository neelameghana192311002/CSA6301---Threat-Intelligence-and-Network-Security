# %% [markdown]
# <a href="https://colab.research.google.com/github/neelameghana192311002/CSA6301---Threat-Intelligence-and-Network-Security/blob/main/ClassActivity/Ex4_Packet_Sniffing_SCAFY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scapy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 30.0 MB/s eta 0:00:00
# ...

# %%
from scapy.all import sniff

def show_packet(packet):
    print(packet.summary())

print("Capturing 5 packets...")

sniff(prn=show_packet, count=5)
# Out:
# Capturing 5 packets...
# Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:40392 PA / Raw
# Ether / IP / TCP 172.28.0.1:40392 > 172.28.0.12:8080 A
# Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:40392 PA / Raw
# Ether / IP / TCP 172.28.0.1:40392 > 172.28.0.12:8080 A
# Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:40392 PA / Raw
# <Sniffed: TCP:5 UDP:0 ICMP:0 Other:0>

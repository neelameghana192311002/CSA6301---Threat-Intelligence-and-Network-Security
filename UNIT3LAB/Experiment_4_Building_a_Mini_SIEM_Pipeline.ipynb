# %% [markdown]
# <a href="https://colab.research.google.com/github/neelameghana192311002/CSA6301---Threat-Intelligence-and-Network-Security/blob/main/UNIT3LAB/Experiment_4_Building_a_Mini_SIEM_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
raw_events = [
    {
        "source": "firewall",
        "ip": "45.33.32.156",
        "event": "blocked"
    },
    {
        "source": "antivirus",
        "host": "WIN10-05",
        "event": "malware_detected",
        "file": "invoice.exe"
    },
    {
        "source": "server",
        "event": "login_success",
        "user": "admin"
    },
]


def normalize(events):
    return [
        {
            "source": e["source"],
            "event_type": e["event"],
            "severity": (
                "high"
                if e["event"] in (
                    "malware_detected",
                    "blocked"
                )
                else "low"
            ),
        }
        for e in events
    ]


def correlation_engine(normalized_events):
    return [
        e
        for e in normalized_events
        if e["severity"] == "high"
    ]


def generate_alerts(high_severity_events):
    return [
        f"ALERT: {e['source']} reported {e['event_type']}"
        for e in high_severity_events
    ]


normalized = normalize(raw_events)

correlated = correlation_engine(normalized)

siem_alerts = generate_alerts(correlated)


print("Normalized:", normalized)

print(
    "Correlated (high severity):",
    correlated
)

print("Alerts:", siem_alerts)
# Out:
# Normalized: [{'source': 'firewall', 'event_type': 'blocked', 'severity': 'high'}, {'source': 'antivirus', 'event_type': 'malware_detected', 'severity': 'high'}, {'source': 'server', 'event_type': 'login_success', 'severity': 'low'}]
# Correlated (high severity): [{'source': 'firewall', 'event_type': 'blocked', 'severity': 'high'}, {'source': 'antivirus', 'event_type': 'malware_detected', 'severity': 'high'}]
# Alerts: ['ALERT: firewall reported blocked', 'ALERT: antivirus reported malware_detected']

# %%
def test_experiment4():
    assert len(normalized) == 3

    assert (
        len(correlated) == 2
    ), "Only the 2 high-severity events should reach correlation"

    assert len(siem_alerts) == 2

    assert all(
        a.startswith("ALERT:")
        for a in siem_alerts
    )

    print("Experiment 4: All test cases passed.")


test_experiment4()
# Out:
# Experiment 4: All test cases passed.

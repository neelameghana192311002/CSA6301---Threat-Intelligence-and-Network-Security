# %% [markdown]
# <a href="https://colab.research.google.com/github/neelameghana192311002/CSA6301---Threat-Intelligence-and-Network-Security/blob/main/MODEL%20PRACTICAL/33_Incident_Response_Lifecycle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = input("Enter action description: ").lower()

if "prepare" in text or "training" in text:
    print("Preparation")
elif "detect" in text or "identify" in text:
    print("Identification")
elif "isolate" in text or "block" in text:
    print("Containment")
elif "remove" in text or "delete" in text:
    print("Eradication")
elif "restore" in text:
    print("Recovery")
elif "lesson" in text or "review" in text:
    print("Lessons Learned")
else:
    print("Unknown")
# Out:
# Enter action description: The infected computer was isolated from the network
# Containment

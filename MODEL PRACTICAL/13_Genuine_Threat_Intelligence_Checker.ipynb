# %% [markdown]
# <a href="https://colab.research.google.com/github/neelameghana192311002/CSA6301---Threat-Intelligence-and-Network-Security/blob/main/MODEL%20PRACTICAL/13_Genuine_Threat_Intelligence_Checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = input("Enter collected data: ").lower()

context = "context" in data
confidence = "confidence" in data
action = "action" in data

if context and confidence and action:
    print("This is Genuine Threat Intelligence")
else:
    print("This is Raw/Unprocessed Data")
# Out:
# Enter collected data: This threat has context, high confidence, and requires immediate action
# This is Genuine Threat Intelligence

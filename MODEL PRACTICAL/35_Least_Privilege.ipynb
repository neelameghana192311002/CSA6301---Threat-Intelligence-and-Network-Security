# %% [markdown]
# <a href="https://colab.research.google.com/github/neelameghana192311002/CSA6301---Threat-Intelligence-and-Network-Security/blob/main/MODEL%20PRACTICAL/35_Least_Privilege.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
required = ["read", "write"]

user_permissions = input(
    "Enter user permissions separated by space: "
).lower().split()

for permission in user_permissions:
    if permission not in required:
        print("Excess permission:", permission)
# Out:
# Enter user permissions separated by space: read write delete
# Excess permission: delete

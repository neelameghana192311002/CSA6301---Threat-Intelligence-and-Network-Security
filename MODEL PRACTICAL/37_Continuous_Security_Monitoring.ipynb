# %% [markdown]
# <a href="https://colab.research.google.com/github/neelameghana192311002/CSA6301---Threat-Intelligence-and-Network-Security/blob/main/MODEL%20PRACTICAL/37_Continuous_Security_Monitoring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
events = ["success", "failed", "failed", "failed", "failed"]

failures = 0

for event in events:
    print("Monitoring:", event)

    if event == "failed":
        failures += 1

    if failures >= 3:
        print("ANOMALY DETECTED")
        break
# Out:
# Monitoring: success
# Monitoring: failed
# Monitoring: failed
# Monitoring: failed
# ANOMALY DETECTED

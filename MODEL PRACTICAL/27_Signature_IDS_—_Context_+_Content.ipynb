# %% [markdown]
# <a href="https://colab.research.google.com/github/neelameghana192311002/CSA6301---Threat-Intelligence-and-Network-Security/blob/main/MODEL%20PRACTICAL/27_Signature_IDS_%E2%80%94_Context_%2B_Content.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
protocol = input("Enter protocol: ").lower()
port = int(input("Enter port: "))
content = input("Enter content: ").lower()

if protocol == "tcp" and port == 80 and "attack" in content:
    print("ALERT: Intrusion detected")
else:
    print("No alert")
# Out:
# Enter protocol: tcp
# Enter port: 80
# Enter content: attack
# ALERT: Intrusion detected

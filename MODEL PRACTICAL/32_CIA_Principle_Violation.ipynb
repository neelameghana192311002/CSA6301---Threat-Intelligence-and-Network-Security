# %% [markdown]
# <a href="https://colab.research.google.com/github/neelameghana192311002/CSA6301---Threat-Intelligence-and-Network-Security/blob/main/MODEL%20PRACTICAL/32_CIA_Principle_Violation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
properties = [
    ("Encryption", "Confidentiality", True),
    ("File integrity", "Integrity", False),
    ("Backup", "Availability", True)
]

for name, cia, status in properties:
    if status == False:
        print("CIA violation:", cia)
# Out:
# CIA violation: Integrity

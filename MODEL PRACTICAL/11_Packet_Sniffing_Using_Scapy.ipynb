# %% [markdown]
# <a href="https://colab.research.google.com/github/neelameghana192311002/CSA6301---Threat-Intelligence-and-Network-Security/blob/main/MODEL%20PRACTICAL/11_Packet_Sniffing_Using_Scapy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scapy
# Out:
# Collecting scapy
#   Downloading scapy-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading scapy-2.7.0-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 15.5 MB/s eta 0:00:00
# Installing collected packages: scapy
# Successfully installed scapy-2.7.0

# %%
from scapy.all import sniff

def show_packet(packet):
    print(packet.summary())

print("Capturing packets...")

sniff(prn=show_packet, count=10)
# Out:
# /usr/local/lib/python3.13/dist-packages/scapy/layers/tls/crypto/groups.py:25: CryptographyDeprecationWarning: Diffie-Hellman over finite fields (FFDH) is deprecated and support will be removed in a future release. Use a more modern key exchange algorithm.
#   from cryptography.hazmat.primitives.asymmetric.dh import DHParameterNumbers
# Capturing packets...
# Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:45572 PA / Raw
# Ether / IP / TCP 172.28.0.1:45572 > 172.28.0.12:8080 A
# Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:45572 PA / Raw
# Ether / IP / TCP 172.28.0.1:45572 > 172.28.0.12:8080 A
# Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:45572 PA / Raw
# Ether / IP / TCP 172.28.0.1:45572 > 172.28.0.12:8080 A
# Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:45572 PA / Raw
# Ether / IP / TCP 172.28.0.1:45572 > 172.28.0.12:8080 A
# Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:45572 PA / Raw
# Ether / IP / TCP 172.28.0.1:45572 > 172.28.0.12:8080 A
# <Sniffed: TCP:10 UDP:0 ICMP:0 Other:0>

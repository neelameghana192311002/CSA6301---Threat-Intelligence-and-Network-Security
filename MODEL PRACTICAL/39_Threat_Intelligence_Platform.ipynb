# %% [markdown]
# <a href="https://colab.research.google.com/github/neelameghana192311002/CSA6301---Threat-Intelligence-and-Network-Security/blob/main/MODEL%20PRACTICAL/39_Threat_Intelligence_Platform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ioc = input("Enter IOC: ").lower()

internal_logs = [
    "login from 10.0.0.5",
    "connection from 192.168.1.10",
    "connection from 10.0.0.5"
]

print("Normalized IOC:", ioc)

for log in internal_logs:
    if ioc in log:
        print("ALERT: IOC matched!")
        break
else:
    print("No match found")
# Out:
# Enter IOC: 10.0.0.5
# Normalized IOC: 10.0.0.5
# ALERT: IOC matched!

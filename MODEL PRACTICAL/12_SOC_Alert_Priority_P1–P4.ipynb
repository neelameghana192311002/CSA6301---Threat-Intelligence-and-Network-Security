# %% [markdown]
# <a href="https://colab.research.google.com/github/neelameghana192311002/CSA6301---Threat-Intelligence-and-Network-Security/blob/main/MODEL%20PRACTICAL/12_SOC_Alert_Priority_P1%E2%80%93P4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
alert = input("Enter SOC alert: ").lower()

if "ransomware" in alert or "data breach" in alert:
    print("Priority: P1 - Critical")

elif "malware" in alert or "server down" in alert:
    print("Priority: P2 - High")

elif "failed login" in alert or "port scan" in alert:
    print("Priority: P3 - Medium")

else:
    print("Priority: P4 - Low")
# Out:
# Enter SOC alert: Ransomware detected on company server
# Priority: P1 - Critical

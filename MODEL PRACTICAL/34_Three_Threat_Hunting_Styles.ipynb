# %% [markdown]
# <a href="https://colab.research.google.com/github/neelameghana192311002/CSA6301---Threat-Intelligence-and-Network-Security/blob/main/MODEL%20PRACTICAL/34_Three_Threat_Hunting_Styles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = input("Enter activity: ").lower()

if "hypothesis" in data:
    print("Hypothesis-based hunting")
elif "threat intel" in data:
    print("Intelligence-based hunting")
elif "unusual" in data or "anomaly" in data:
    print("Analytics-based hunting")
else:
    print("Unknown hunting style")
# Out:
# Enter activity: We search for unusual login behavior
# Analytics-based hunting

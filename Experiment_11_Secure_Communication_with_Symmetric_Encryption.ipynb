# %% [markdown]
# <a href="https://colab.research.google.com/github/neelameghana192311002/CSA6301---Threat-Intelligence-and-Network-Security/blob/main/Experiment_11_Secure_Communication_with_Symmetric_Encryption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cryptography
# Out:
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (49.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography) (2.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography) (3.0)

# %%
from cryptography.fernet import Fernet

# Step 1: Generate a shared secret key (both sender & receiver need this)
key = Fernet.generate_key()
cipher = Fernet(key)

# Step 2: Sender encrypts the message before sending over the network
message = b"Transfer $500 to account 12345"

encrypted = cipher.encrypt(message)

print("Encrypted (what an eavesdropper sees):")
print(encrypted)

# Step 3: Receiver decrypts it using the same key
decrypted = cipher.decrypt(encrypted)

print("Decrypted (what the receiver reads):")
print(decrypted.decode())
# Out:
# Encrypted (what an eavesdropper sees):
# b'gAAAAABqYZz-cy2h8WB_p8EhyXx2PUMdU4e1v19hp5iLBs-Gk-m6lSQsk2aPeth520OESTqInwroREhjutuqzwxgu9OlaS8Jg2zHYDwooPESGnA8U7Hogu4='
# Decrypted (what the receiver reads):
# Transfer $500 to account 12345
